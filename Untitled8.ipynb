# %%
import numpy as np
import pandas as pd

# %%
data=pd.ExcelFile("/home/koushik/Downloads/Suspense with PID 01.29.16.xlsx")

# %%
data.sheet_names
# Out:
# [u'Overall', u'PP', u'LAS', u'Sheet13', u'MGA']

# %%
df=data.parse("Overall")

# %%
df.columns
# Out:
# Index([u'GROUP NBR', u'ACCT', u'GROUP NAME', u'AM', u'RA', u'SUSPENSE',
#        u'SYSPENSE TYPE', u'CREATION DATE', u'PID', u'COVG TERM DATE',
#        u'REASON CODE', u'TERM CODE', u'TERM DESC', u'SUPERVISOR',
#        u'Billing Code'],
#       dtype='object')

# %%
df.iloc[:,5]
# Out:
# numpy.float64

# %%
data2=pd.ExcelFile("/home/koushik/Downloads/Suspense with PID 02.29.16.xlsx")

# %%
data = pd.ExcelFile("/home/koushik/Downloads/90% Proc Query since 2010 (3).xlsx")

# %%
data.sheet_names
# Out:
# [u'Sheet1', u'Report 1']

# %%
df=data.parse("Report 1")

# %%
df.iloc[2,:]['Apps Recd Day']
# Out:
# 9

# %%
len(df)
# Out:
# 281020

# %%
tr=[]
tr.iloc[1] = df.iloc[1]['GRPNUM']
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-32-c6eeff1c8af8> in <module>()
#       1 tr=[]
# ----> 2 tr.iloc[1] = df.iloc[1]['GRPNUM']
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
data_apps=[]
k=0;
i=0
for i in range(0,len(df)):
    if df.iloc[i,:]['Apps Recd Yr'] == 2015:
        data_apps.append(df.iloc[i])

# %%
len(data_apps)
# Out:
# 43839

# %%
data_apps[1]
# Out:
# GRPNUM                                       0000003433
# Batch ID           627D016E-8292-E411-B031-0050569D3711
# App Recd Date                       2015-01-02 00:00:00
# Apps Recd Mo                                          1
# Apps Recd Day                                         2
# Apps Recd Yr                                       2015
# Enroll Start                        2014-09-24 00:00:00
# Apps Recd Count                                      28
# Apps Proc Count                                      28
# Application Age                                     NaN
# Name: 173606, dtype: object

# %%
data_apps[1]['Apps Recd Count']
# Out:
# 28

# %%
for i in range(0,len(data_apps)):
    for j in range(0,i):
        if data_apps[i].GRPNUM == data_apps[j].GRPNUM:
            data_apps[j]['Apps Recd Count'] = data_apps[i]['Apps Recd Count'] + data_apps[j]['Apps Recd Count']
            data_apps[j]['Apps Proc Count'] = data_apps[i]['Apps Proc Count'] + data_apps[j]['Apps Proc Count']
            del data_apps[i]
            break
# Out:
# /home/koushik/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/koushik/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
if np.where()

# %%
df[1]
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-29-dc0ea82142cb> in <module>()
# ----> 1 df[1]
#
# /home/koushik/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /home/koushik/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /home/koushik/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
# ...

# %%
data_apps
# Out:
# []

# %%
df = pd.read_excel(open('/home/koushik/Downloads/Suspense with PID 02.29.16.xlsx','rb'), sheetname='Overall')
# Out:
# /home/koushik/anaconda2/lib/python2.7/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
data2.sheet_names
# Out:
# [u'Overall', u'PP', u'LAS', u'Sheet13', u'MGA']

# %%
df
# Out:
#          GROUP NBR  ACCT                                         GROUP NAME  \
# 0       0000019286   100                                       PGA TOUR INC
# 1       0000019241   700                                  THE CITY OF COCOA
# 2       0000006061   700                                   DELHAIZE AMERICA
# 3       0000011052   100                                  TIRE CENTERS, LLC
# 4       0000018354   700                           TEAMSTERS LOCAL 848 (CA)
# 5       0000021107   300  AEGIS MEDIA AMERICAS, INC. DBA DENTSU AEGIS NE...
# 6       0000010519   700                                 DARDEN RESTAURANTS
# 7       0000019516   700                             PREMIER TRANSPORTATION
# 8       0000012697   700                                       CMH SERVICES
# 9       0000018074   700                            INTERTAPE POLYMER GROUP
# 10      0000021033   100                            GENESIS HEALTH CARE LLC
# ...

# %%
i=3
trail = pd.read_csv("/home/koushik/Downloads/Groups At Risk 20170320.xlsx - Groups At Risk Data Tab + "i" + 20.csv")
# Out:
#   File "<ipython-input-26-0407c68a4c91>", line 2
#     trail = pd.read_csv("/home/koushik/Downloads/Groups At Risk 20170320.xlsx - Groups At Risk Data Tab + "i" + 20.csv")
#                                                                                                            ^
# SyntaxError: invalid syntax

# %%
path='/home/koushik/Downloads/try'

# %%
import os
import xlrd

# %%
for xls in os.walk(path):
    print "hello"
# Out:
# hello

# %%
for root,dirs,files in os.walk(path):
    xlsfiles=[ _ for _ in files if _.endswith('.xlsx') ]

# %%
xlsfiles
# Out:
# ['Suspense with PID 02.29.16.xlsx', 'Suspense with PID 01.29.16.xlsx']

# %%
for xls in xlsfiles:
    print xls
# Out:
# Suspense with PID 02.29.16.xlsx
# Suspense with PID 01.29.16.xlsx

# %%
data=[]
for xls in xlsfiles:
    data=pd.ExcelFile(xls)
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-40-ee036a542e82> in <module>()
#       1 data=[]
#       2 for xls in xlsfiles:
# ----> 3     data=pd.ExcelFile(xls)
#
# /home/koushik/anaconda2/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     292             self.book = xlrd.open_workbook(file_contents=data)
#     293         elif isinstance(self._io, compat.string_types):
# --> 294             self.book = xlrd.open_workbook(self._io)
#     295         else:
#     296             raise ValueError('Must explicitly set engine if not passing in'
#
# /home/koushik/anaconda2/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     114         peek = file_contents[:peeksz]
#     115     else:
# --> 116         with open(filename, "rb") as f:
#     117             peek = f.read(peeksz)
# ...

# %%
pwd
# Out:
# u'/home/koushik'

# %%
cwd "/home/koushik/Downloads/try"
# Out:
#   File "<ipython-input-43-308501608b06>", line 1
#     cwd "/home/koushik/Downloads/try"
#                                     ^
# SyntaxError: invalid syntax

# %%
os.chdir("/home/koushik/Downloads/try")

# %%
pwd
# Out:
# u'/home/koushik/Downloads/try'

# %%
data=[]
i=0;
suspense=[]
for xls in xlsfiles:
    data=pd.ExcelFile(xls)
    df=data.parse("Overall")
    suspense.append(df["SUSPENSE"])
    i=i+1

# %%
df=data.parse("Overall")

# %%
df
# Out:
#          GROUP NBR  ACCT                                   GROUP NAME  \
# 0       000000A001   500                      JOHNSTON COUNTY SCHOOLS
# 1       000000A001   500                      JOHNSTON COUNTY SCHOOLS
# 2       000000A001   500                      JOHNSTON COUNTY SCHOOLS
# 3       000000A001   500                      JOHNSTON COUNTY SCHOOLS
# 4       000000A001   501                      JOHNSTON COUNTY SCHOOLS
# 5       000000A001   500                      JOHNSTON COUNTY SCHOOLS
# 6       000000A002   100                      RED ROCK CANYON SCHOOLS
# 7       000000A002   100                      RED ROCK CANYON SCHOOLS
# 8       000000A002   100                      RED ROCK CANYON SCHOOLS
# 9       0000000002   300                                        AFLAC
# 10      0000000002   300                                        AFLAC
# 11      0000000002   300                                        AFLAC
# ...

# %%
i=2
susp = []
susp.append(df['SUSPENSE'])

# %%
susp.append(df['AM'])

# %%
len(susp)
# Out:
# 2

# %%
susp_arr=np.asarray(susp)

# %%
susp_arr.shape
# Out:
# (2, 402180)

# %%
susp_arr[1][2
           ]
# Out:
# 53.28

# %%
len(suspense)
# Out:
# 2

# %%
suspense_arr=np.asarray(suspense)

# %%
suspense_arr.shape
# Out:
# (2,)

# %%
suspense_arr[1][:]
# Out:
# 0          9.18
# 1         18.36
# 2         20.50
# 3         15.00
# 4         20.84
# 5         43.94
# 6         21.58
# 7          4.43
# 8         33.41
# 9          3.73
# 10         5.66
# 11         2.62
# 12        42.92
# 13        31.74
# 14        15.87
# 15        46.94
# 16        62.14
# 17        34.38
# 18        15.20
# 19        30.40
# 20        25.16
# 21         4.56
# 22         5.00
# 23         2.61
# 24        34.29
# 25         3.47
# 26         1.21
# 27         3.24
# 28        16.58
# 29        78.42
#           ...
# 335194     0.45
# 335195    37.65
# 335196     1.09
# 335197    29.77
# 335198    22.84
# 335199     1.20
# 335200    58.90
# 335201    29.57
# 335202    30.59
# 335203     1.69
# 335204     6.53
# 335205    42.09
# 335206    34.86
# 335207    33.53
# 335208     7.18
# 335209    34.62
# 335210    59.10
# 335211     1.62
# 335212    42.09
# 335213    27.57
# 335214    45.42
# 335215    46.17
# 335216    12.32
# 335217    50.27
# ...

# %%
df.columns
# Out:
# Index([u'GROUP NBR', u'ACCT', u'GROUP NAME', u'AM', u'RA', u'SUSPENSE',
#        u'SYSPENSE TYPE', u'CREATION DATE', u'PID', u'COVG TERM DATE',
#        u'REASON CODE', u'TERM CODE', u'TERM DESC', u'SUPERVISOR',
#        u'Billing Code'],
#       dtype='object')
