# %%
import pandas as pd
import numpy as np
data = pd.ExcelFile("/home/koushik/Downloads/90% Proc Query since 2010 (3).xlsx")

# %%
df=data.parse("Report 1")

# %%
df.columns
# Out:
# Index([u'GRPNUM', u'Batch ID', u'App Recd Date', u'Apps Recd Mo',
#        u'Apps Recd Day', u'Apps Recd Yr', u'Enroll Start', u'Apps Recd Count',
#        u'Apps Proc Count', u'Application Age'],
#       dtype='object')

# %%
dat = df.groupby(['GRPNUM' , 'Apps Recd Yr'])

# %%
dat = df[df['Apps Recd Yr'] == 2015]

# %%
dat.groupby('GRPNUM').agg({"Apps Recd Count" : "sum"})
# Out:
#                          Apps Recd Count
# GRPNUM
# 0000000002                          5823
# 0000000720                            25
# 0000001569                             5
# 0000002256                            87
# 0000003002                             4
# 0000003005                            10
# 0000003007                             4
# 0000003009                             0
# 0000003016                             5
# 0000003020                             3
# 0000003024                            13
# 0000003027                          1039
# 0000003032                             0
# 0000003056                             1
# 0000003058                            11
# 0000003064                             7
# 0000003066                             6
# 0000003075                             1
# 0000003076                            17
# 0000003079                            21
# 0000003086                             9
# 0000003110                             3
# ...

# %%
dat.groupby('GRPNUM', as_index = False).agg({"Apps Proc Count" : "sum"})
# Out:
#                        GRPNUM  Apps Proc Count
# 0                  0000000002             5653
# 1                  0000000720               25
# 2                  0000001569                5
# 3                  0000002256               79
# 4                  0000003002                4
# 5                  0000003005                1
# 6                  0000003007                4
# 7                  0000003009                0
# 8                  0000003016                1
# 9                  0000003020                3
# 10                 0000003024               13
# 11                 0000003027             1021
# 12                 0000003032                0
# 13                 0000003056                1
# 14                 0000003058               11
# 15                 0000003064                7
# 16                 0000003066                0
# 17                 0000003075                1
# 18                 0000003076               17
# ...

# %%
data_apps.GRPNUM
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-15-9e0c5e898764> in <module>()
# ----> 1 data_apps.GRPNUM
#
# AttributeError: 'list' object has no attribute 'GRPNUM'

# %%
df_l = pd.DataFrame({'Grp':data_apps.GRPNUM})
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-14-b9440f36825e> in <module>()
# ----> 1 df_l = pd.DataFrame({'Grp':data_apps.GRPNUM})
#
# AttributeError: 'list' object has no attribute 'GRPNUM'

# %%
df_l.head(5)
# Out:
#                                                  col
# 0  GRPNUM                                       0...
# 1  GRPNUM                                       0...
# 2  GRPNUM                                       0...
# 3  GRPNUM                                       0...
# 4  GRPNUM                                       0...
