# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/home/koushik/Downloads/Groups At Risk 20170320.xlsx - Groups At Risk Data Tab 0320.csv")

# %%
data["Apps Received"][1:5]
# Out:
# 1     2302
# 2     2761
# 3    37987
# 4      802
# Name: Apps Received, dtype: int64

# %%
data.head(5)
# Out:
#   GroupNumber                             GroupName MKTSEG MGA Group  \
# 0  0000006061                      DELHAIZE AMERICA    PRT       MGA
# 1  0000006722                       UNITED AIRLINES    PRT       MGA
# 2  0000006473              CONTINENTAL AIRLINES AFA    PRT       MGA
# 3  0000022700                      CVS PHARMACY INC    BRK       MGA
# 4  0000021033  GENESIS ADMINISTRATIVE SERVICES, LLC    BRK       NaN
#
#                        Broker Name  BLANK  Apps Received  Apps Processed  \
# 0                        RJC Group    NaN          10705            5085
# 1        National Group Protection    NaN           2302             409
# 2  National Group Protection (NGP)    NaN           2761              27
# 3                              NaN    NaN          37987           36466
# 4                  Charon Planning    NaN            802             765
#
#   90% of Apps Within SLA  G/RO Recd 30   ...    SUS % of IF AP  \
# ...

# %%
data.iloc[:,44:54]
# Out:
#        Days from Last Pmt SUS % of IF AP %Paid/Expected  \
# 0                      14         12.25%        134.37%
# 1                      31         21.81%         77.53%
# 2                      32         14.13%         87.25%
# 3                      47          4.68%        150.68%
# 4                      81          5.18%          3.28%
# 5                      78         14.31%         14.02%
# 6                     -12        -18.79%         95.38%
# 7                      19          9.23%         67.43%
# 8                     139         57.74%         92.23%
# 9                      19         15.69%        152.95%
# 10                      0          0.00%          0.00%
# 11                     47         15.17%        109.27%
# 12                     16         16.93%         90.53%
# 13                    109          0.00%          0.00%
# 14                     19         27.59%         94.72%
# 15                     78          4.50%          2.40%
# ...

# %%
apps_cent = 100*data["Apps Processed"]/data["Apps Received"]

# %%
apps_cent[0:5]
# Out:
# 0    47.501168
# 1    17.767159
# 2     0.977907
# 3    95.995999
# 4    95.386534
# dtype: float64

# %%
apps_cent.fillna(0)
# Out:
# 0         47.501168
# 1         17.767159
# 2          0.977907
# 3         95.995999
# 4         95.386534
# 5         96.923870
# 6         53.549940
# 7         93.950851
# 8         89.542220
# 9         82.548563
# 10        84.245695
# 11        94.169924
# 12        83.805230
# 13         0.000000
# 14        67.838480
# 15        95.592105
# 16        96.876712
# 17        12.748092
# 18        75.841686
# 19       283.599089
# 20        62.009905
# 21        96.885355
# 22        93.656051
# 23        99.990308
# 24        76.935999
# 25        85.869565
# 26         0.000000
# 27        95.185285
# 28        52.405545
# 29        51.768489
#             ...
# 13038      0.000000
# 13039      0.000000
# 13040      0.000000
# 13041      0.000000
# 13042      0.000000
# 13043      0.000000
# 13044      0.000000
# 13045      0.000000
# 13046      0.000000
# 13047      0.000000
# 13048      0.000000
# 13049      0.000000
# 13050      0.000000
# 13051      0.000000
# ...

# %%
data.columns
# Out:
# Index([u'GroupNumber', u'GroupName', u'MKTSEG', u'MGA Group', u'Broker Name',
#        u'BLANK', u'Apps Received', u'Apps Processed',
#        u'90% of Apps Within SLA', u'G/RO Recd 30', u'Set-Up 15', u'BLANK.1',
#        u'ACTMGR', u'STOPLIGHT', u'Monthly Premium', u'Credit Balance',
#        u'Credit Percentage', u'BLANK.2', u'AIC', u'ARM', u'Broker',
#        u'% of Milestones Met/Not past due', u'Billing Admin', u'BLANK.3',
#        u'Platform', u'Platform Data', u'BLANK.4', u'Oldest Case Age (days)',
#        u'Active Case Age', u'Active Case Count', u'YTD Cases Overall',
#        u'Active Cases Over 40', u'BLANK.5', u'Inforce AP', u'IF AP 3/13',
#        u'Weekly Gain/Loss', u'Monthly Premium.1', u'Unapplied Batches',
#        u'Applied within 30', u'Unknown Suspense', u'PID Count',
#        u'Specific Suspense', u'PID Count.1', u'Total Suspense (Unk and Spec)',
#        u'Days from Last Pmt', u'SUS % of IF AP', u'%Paid/Expected',
# ...

# %%
for i in range(len(data['G/RO Recd 30'])):
    if data['G/RO Recd 30'][i] >= 30:
        data['G/RO Recd 30'][i] = 3
    elif data['G/RO Recd 30'][i] <= 35:
        data['G/RO Recd 30'][i] = 1
    else :
        data['G/RO Recd 30'][i] = 2
# Out:
# /home/koushik/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/koushik/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
len(data['G/RO Recd 30'])
# Out:
# 13068

# %%
setup = data['Set-Up 15']

# %%
for i in range(len(setup)):
    if setup[i] >= 30:
        setup[i] = 3
    elif setup[i] <= 35:
        setup[i] = 1
    else :
        setup[i] = 2
# Out:
# /home/koushik/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/koushik/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
setup_range = []

# %%
setup
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        3
# 5        1
# 6        1
# 7        1
# 8        3
# 9        3
# 10       1
# 11       3
# 12       3
# 13       1
# 14       3
# 15       1
# 16       3
# 17       1
# 18       3
# 19       3
# 20       1
# 21       3
# 22       3
# 23       3
# 24       3
# 25       3
# 26       1
# 27       1
# 28       1
# 29       3
#         ..
# 13038    1
# 13039    1
# 13040    1
# 13041    1
# 13042    1
# 13043    1
# 13044    1
# 13045    1
# 13046    1
# 13047    1
# 13048    1
# 13049    1
# 13050    1
# 13051    1
# 13052    1
# 13053    1
# 13054    1
# 13055    1
# 13056    1
# 13057    1
# 13058    1
# 13059    1
# 13060    1
# 13061    1
# 13062    1
# 13063    1
# 13064    1
# 13065    1
# 13066    1
# 13067    1
# Name: Set-Up 15, Length: 13068, dtype: int64

# %%
data.columns
# Out:
# Index([u'GroupNumber', u'GroupName', u'MKTSEG', u'MGA Group', u'Broker Name',
#        u'BLANK', u'Apps Received', u'Apps Processed',
#        u'90% of Apps Within SLA', u'G/RO Recd 30', u'Set-Up 15', u'BLANK.1',
#        u'ACTMGR', u'STOPLIGHT', u'Monthly Premium', u'Credit Balance',
#        u'Credit Percentage', u'BLANK.2', u'AIC', u'ARM', u'Broker',
#        u'% of Milestones Met/Not past due', u'Billing Admin', u'BLANK.3',
#        u'Platform', u'Platform Data', u'BLANK.4', u'Oldest Case Age (days)',
#        u'Active Case Age', u'Active Case Count', u'YTD Cases Overall',
#        u'Active Cases Over 40', u'BLANK.5', u'Inforce AP', u'IF AP 3/13',
#        u'Weekly Gain/Loss', u'Monthly Premium.1', u'Unapplied Batches',
#        u'Applied within 30', u'Unknown Suspense', u'PID Count',
#        u'Specific Suspense', u'PID Count.1', u'Total Suspense (Unk and Spec)',
#        u'Days from Last Pmt', u'SUS % of IF AP', u'%Paid/Expected',
# ...
